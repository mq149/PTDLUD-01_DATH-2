# %% [markdown]
# Yêu cầu này có thể sử dụng 2 dataset từ 2 bảng FactInternetSales (để train/test), bảng DimCustomer để lấy thông tin những khách đã mua hàng (train/test) và lấy thông tin những khách chưa mua hàng (để predict)
