# %% [markdown]
# # Chuẩn bị dữ liệu

# %%
# Uncomment và chạy để cài đặt thư viện pmdarima
#pip install pmdarima

# %%
import pyodbc
import pandas as pd
import numpy as np
import math
import warnings
warnings.filterwarnings('ignore')

# %%
server_name = 'DESKTOP-TOL1F2F\MSSQLSERVERBI'
database_name = 'AdventureWorksDW2012'

connection = pyodbc.connect('Driver={SQL Server}; Server=' + server_name +
                      '; Database=' + database_name +
                      '; Trusted_Connection=yes;')

# %%
df = pd.read_sql_query("SELECT * FROM [dbo].[FactInternetSales];", connection) 

df.head()
# Out:
#    ProductKey  OrderDateKey  DueDateKey  ShipDateKey  CustomerKey  \
# 0         310      20101229    20110110     20110105        21768
# 1         346      20101229    20110110     20110105        28389
# 2         346      20101229    20110110     20110105        25863
# 3         336      20101229    20110110     20110105        14501
# 4         346      20101229    20110110     20110105        11003
#
#    PromotionKey  CurrencyKey  SalesTerritoryKey SalesOrderNumber  \
# 0             1           19                  6          SO43697
# 1             1           39                  7          SO43698
# 2             1          100                  1          SO43699
# 3             1          100                  4          SO43700
# 4             1            6                  9          SO43701
#
#    SalesOrderLineNumber  ...  ProductStandardCost  TotalProductCost  \
# 0                     1  ...            2171.2942         2171.2942
# 1                     1  ...            1912.1544         1912.1544
# 2                     1  ...            1912.1544         1912.1544
# 3                     1  ...             413.1463          413.1463
# 4                     1  ...            1912.1544         1912.1544
#
#    SalesAmount    TaxAmt  Freight  CarrierTrackingNumber  CustomerPONumber  \
# 0    3578.2700  286.2616  89.4568                   None              None
# 1    3399.9900  271.9992  84.9998                   None              None
# 2    3399.9900  271.9992  84.9998                   None              None
# 3     699.0982   55.9279  17.4775                   None              None
# 4    3399.9900  271.9992  84.9998                   None              None
#
#    OrderDate    DueDate   ShipDate
# 0 2010-12-29 2011-01-10 2011-01-05
# 1 2010-12-29 2011-01-10 2011-01-05
# 2 2010-12-29 2011-01-10 2011-01-05
# 3 2010-12-29 2011-01-10 2011-01-05
# 4 2010-12-29 2011-01-10 2011-01-05
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Loại bỏ các thuộc tính không sử dụng

# %%
to_be_removed = ['id', 'ID', 'Key', 'Number', 'CreditCardApprovalCode', 'Comment']
for col in df.columns:
    for r in to_be_removed:
        if r in col:
            df.drop(columns=[col], inplace=True)

df.head()
# Out:
#    OrderQuantity  UnitPrice  ExtendedAmount  UnitPriceDiscountPct  \
# 0              1  3578.2700       3578.2700                   0.0
# 1              1  3399.9900       3399.9900                   0.0
# 2              1  3399.9900       3399.9900                   0.0
# 3              1   699.0982        699.0982                   0.0
# 4              1  3399.9900       3399.9900                   0.0
#
#    DiscountAmount  ProductStandardCost  TotalProductCost  SalesAmount  \
# 0             0.0            2171.2942         2171.2942    3578.2700
# 1             0.0            1912.1544         1912.1544    3399.9900
# 2             0.0            1912.1544         1912.1544    3399.9900
# 3             0.0             413.1463          413.1463     699.0982
# 4             0.0            1912.1544         1912.1544    3399.9900
#
#      TaxAmt  Freight  OrderDate    DueDate   ShipDate
# 0  286.2616  89.4568 2010-12-29 2011-01-10 2011-01-05
# 1  271.9992  84.9998 2010-12-29 2011-01-10 2011-01-05
# 2  271.9992  84.9998 2010-12-29 2011-01-10 2011-01-05
# 3   55.9279  17.4775 2010-12-29 2011-01-10 2011-01-05
# 4  271.9992  84.9998 2010-12-29 2011-01-10 2011-01-05

# %% [markdown]
# ## Loại bỏ dữ liệu trùng lặp

# %%
# Kiểm tra dữ liệu trùng lặp
df.duplicated(subset=None, keep='first')
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 60393     True
# 60394     True
# 60395     True
# 60396    False
# 60397     True
# Length: 60398, dtype: bool

# %%
# Loại bỏ trùng lặp
df.drop_duplicates(inplace=True)
print(df.head())
df.shape
# Out:
#    OrderQuantity  UnitPrice  ExtendedAmount  UnitPriceDiscountPct  \
# 0              1  3578.2700       3578.2700                   0.0
# 1              1  3399.9900       3399.9900                   0.0
# 3              1   699.0982        699.0982                   0.0
# 5              1  3578.2700       3578.2700                   0.0
# 7              1  3374.9900       3374.9900                   0.0
#
#    DiscountAmount  ProductStandardCost  TotalProductCost  SalesAmount  \
# 0             0.0            2171.2942         2171.2942    3578.2700
# 1             0.0            1912.1544         1912.1544    3399.9900
# 3             0.0             413.1463          413.1463     699.0982
# 5             0.0            2171.2942         2171.2942    3578.2700
# 7             0.0            1898.0944         1898.0944    3374.9900
#
#      TaxAmt  Freight  OrderDate    DueDate   ShipDate
# 0  286.2616  89.4568 2010-12-29 2011-01-10 2011-01-05
# 1  271.9992  84.9998 2010-12-29 2011-01-10 2011-01-05
# 3   55.9279  17.4775 2010-12-29 2011-01-10 2011-01-05
# 5  286.2616  89.4568 2010-12-30 2011-01-11 2011-01-06
# 7  269.9992  84.3748 2010-12-30 2011-01-11 2011-01-06
# (13979, 13)

# %% [markdown]
# # Thống kê mô tả
# 1. Thống kê kích thước tập dữ liệu
# 2. Thống kê các độ đo trung tâm, phân tán
# 3. Thống kê số lượng dữ liệu missing

# %% [markdown]
# ## 1. Thống kê kích thước tập dữ liệu
# - Tập dữ liệu được chọn có kích thước 13 cột và 13979 dòng (đã lược bỏ dòng trùng từ 60398 dòng)
# - Có 3 thuộc tính kiểu thời gian là OrderDate, DueDate, ShipDate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13979 entries, 0 to 60396
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderQuantity         13979 non-null  int64
#  1   UnitPrice             13979 non-null  float64
#  2   ExtendedAmount        13979 non-null  float64
#  3   UnitPriceDiscountPct  13979 non-null  float64
#  4   DiscountAmount        13979 non-null  float64
#  5   ProductStandardCost   13979 non-null  float64
#  6   TotalProductCost      13979 non-null  float64
#  7   SalesAmount           13979 non-null  float64
#  8   TaxAmt                13979 non-null  float64
#  9   Freight               13979 non-null  float64
#  10  OrderDate             13979 non-null  datetime64[ns]
#  11  DueDate               13979 non-null  datetime64[ns]
#  12  ShipDate              13979 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(9), int64(1)
# memory usage: 1.5 MB

# %% [markdown]
# ## 2. Thống kê các độ đo trung tâm, phân tán
# - Tham số datetime_is_numeric=True để tắt đi cảnh báo dữ liệu thời gian khi chạy hàm describe()

# %%
df.describe(datetime_is_numeric=True)
# Out:
#        OrderQuantity     UnitPrice  ExtendedAmount  UnitPriceDiscountPct  \
# count        13979.0  13979.000000    13979.000000               13979.0
# mean             1.0    758.360649      758.360649                   0.0
# min              1.0      2.290000        2.290000                   0.0
# 25%              1.0     24.490000       24.490000                   0.0
# 50%              1.0     54.990000       54.990000                   0.0
# 75%              1.0   1214.850000     1214.850000                   0.0
# max              1.0   3578.270000     3578.270000                   0.0
# std              0.0   1042.780509     1042.780509                   0.0
#
#        DiscountAmount  ProductStandardCost  TotalProductCost   SalesAmount  \
# count         13979.0         13979.000000      13979.000000  13979.000000
# mean              0.0           445.762099        445.762099    758.360649
# min               0.0             0.856500          0.856500      2.290000
# 25%               0.0             9.159300          9.159300     24.490000
# 50%               0.0            38.492300         38.492300     54.990000
# 75%               0.0           755.150800        755.150800   1214.850000
# max               0.0          2171.294200       2171.294200   3578.270000
# std               0.0           618.145602        618.145602   1042.780509
#
#              TaxAmt       Freight                      OrderDate  \
# count  13979.000000  13979.000000                          13979
# mean      60.668854     18.959057  2013-04-20 10:51:26.744402176
# min        0.183200      0.057300            2010-12-29 00:00:00
# 25%        1.959200      0.612300            2013-02-12 00:00:00
# 50%        4.399200      1.374800            2013-06-07 00:00:00
# 75%       97.188000     30.371300            2013-09-28 00:00:00
# max      286.261600     89.456800            2014-01-28 00:00:00
# std       83.422443     26.069515                            NaN
#
#                              DueDate                       ShipDate
# count                          13979                          13979
# mean   2013-05-02 10:51:26.744402176  2013-04-27 10:51:26.744402432
# min              2011-01-10 00:00:00            2011-01-05 00:00:00
# 25%              2013-02-24 00:00:00            2013-02-19 00:00:00
# 50%              2013-06-19 00:00:00            2013-06-14 00:00:00
# 75%              2013-10-10 00:00:00            2013-10-05 00:00:00
# max              2014-02-09 00:00:00            2014-02-04 00:00:00
# std                              NaN                            NaN

# %% [markdown]
# ## 3. Thống kê số lượng dữ liệu missing
# - Tập dữ liệu chọn ra có dữ liệu đầy đủ trên các cột

# %%
df.isna().sum()
# Out:
# OrderQuantity           0
# UnitPrice               0
# ExtendedAmount          0
# UnitPriceDiscountPct    0
# DiscountAmount          0
# ProductStandardCost     0
# TotalProductCost        0
# SalesAmount             0
# TaxAmt                  0
# Freight                 0
# OrderDate               0
# DueDate                 0
# ShipDate                0
# dtype: int64

# %% [markdown]
# # Xử lý dữ liệu
# Tính tổng doanh thu theo từng tháng của năm phục vụ cho trực quan hoá dữ liệu theo thời gian.

# %%
# Chỉ lấy 2 thuộc tính là OrderDate và SalesAmount
df = df[['OrderDate', 'SalesAmount']]
# Xử lý OrderDate, tính SalesAmount theo từng tháng của năm

df = df.groupby(pd.Grouper(key='OrderDate', freq='M')).sum()
df = df.sort_index()
df.head()
# Out:
#             SalesAmount
# OrderDate
# 2010-12-31   22307.9764
# 2011-01-31  180290.3684
# 2011-02-28  166530.8856
# 2011-03-31  146783.0066
# 2011-04-30  174303.7448

# %% [markdown]
# # Trực quan hoá dữ liệu

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Doanh thu qua từng năm

# %%
plt.figure(figsize=(20, 8), dpi=80)
plt.xticks(rotation=30)
plt.title('AdventureWorks Sales Amount over Years (Dec 2010 - Jan 2014)')
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# Nhận xét:
# - Doanh thu thường giảm nhẹ ở đầu năm, tăng nhiều ở dịp cuối năm.
# - Doanh thu tăng trưởng mạnh vào cuối năm 2012 đầu năm 2013

# %% [markdown]
# Nhận thấy được dữ liệu năm 2014 chỉ có ở tháng 1, năm 2010 chỉ có tháng 12. Thực hiện loại bỏ dữ liệu này, chỉ giữ lại khoảng 2011-2013 để dự đoán.

# %%
df = df[(df.index >= pd.to_datetime('2011-01-01')) & (df.index < pd.to_datetime('2014-01-01'))]
df
# Out:
#             SalesAmount
# OrderDate
# 2011-01-31  180290.3684
# 2011-02-28  166530.8856
# 2011-03-31  146783.0066
# 2011-04-30  174303.7448
# 2011-05-31  196636.7212
# 2011-06-30  203857.5194
# 2011-07-31  213586.6712
# 2011-08-31  189112.6430
# 2011-09-30  201136.1266
# 2011-10-31  224360.7394
# 2011-11-30  244457.3994
# 2011-12-31  243180.1179
# 2012-01-31  224392.1226
# 2012-02-29  222381.8508
# 2012-03-31  206867.5905
# 2012-04-30  204138.0354
# 2012-05-31  232380.5285
# 2012-06-30  246685.0515
# 2012-07-31  232292.3918
# 2012-08-31  255736.1928
# 2012-09-30  240192.9422
# 2012-10-31  244147.7933
# 2012-11-30  249710.2827
# 2012-12-31  291312.4622
# 2013-01-31  389626.7400
# 2013-02-28  355456.0800
# 2013-03-31  425369.6000
# 2013-04-30  423906.9100
# 2013-05-31  462180.2600
# 2013-06-30  472585.4300
# 2013-07-31  475306.8100
# 2013-08-31  483126.8600
# 2013-09-30  456807.3100
# 2013-10-31  473636.2800
# 2013-11-30  463740.9400
# 2013-12-31  445729.0700

# %%
plt.figure(figsize=(20, 8), dpi=80)
plt.xticks(rotation=30)
plt.title('AdventureWorks Sales Amount over Years (2011 - 2013)')
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# ## Doanh thu giữa các tháng qua từng năm

# %%
def make_seasonal_plot():
    df_copy = df.copy()
    df_copy['year'] = [d.year for d in df_copy.index]
    df_copy['month'] = [d.strftime('%b') for d in df_copy.index]
    print(df_copy.head())
    years = df_copy['year'].unique()

    # Chuẩn bị màu cho biểu đồ
    np.random.seed(100)
    mycolors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange', 'tab:brown', 'tab:grey', 'tab:pink', 'tab:olive', 'deeppink', 'steelblue', 'firebrick', 'mediumseagreen']

    # Vẽ biểu đồ
    plt.figure(figsize=(16,8), dpi= 80)
    for i, y in enumerate(years):      
        plt.plot('month', 'SalesAmount', data=df_copy.loc[df_copy.year==y, :], color=mycolors[i], label=y)
        plt.text(df_copy.loc[df_copy.year==y, :].shape[0]-.9, df_copy.loc[df_copy.year==y, 'SalesAmount'][-1:].values[0], y, fontsize=12, color=mycolors[i])

    plt.ylabel='Sales Amount'
    plt.xlabel='Month'
    plt.yticks(fontsize=12, alpha=.7)
    plt.title("Seasonal Plot of Adventure Works Internet Sales Amount", fontsize=20)
    plt.show()

make_seasonal_plot()
# Out:
#             SalesAmount  year month
# OrderDate
# 2011-01-31  180290.3684  2011   Jan
# 2011-02-28  166530.8856  2011   Feb
# 2011-03-31  146783.0066  2011   Mar
# 2011-04-30  174303.7448  2011   Apr
# 2011-05-31  196636.7212  2011   May

# %% [markdown]
# Nhận xét:
# - Doanh thu tăng mạnh vào giai đoạn giữa và gần cuối năm, lặp lại qua các năm.
# - Giai đoạn giữa năm có thể là do dịp nghỉ hè của học sinh sinh viên.
# - Giai đoạn cuối năm có thể do dịp nghỉ lễ, khách hàng mua quà tặng cho dịp Giáng sinh.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

sns.set()
plt.rcParams['figure.figsize'] = (14, 9)
result = seasonal_decompose(df, model='multiplicative')
result.plot();

# %% [markdown]
# Nhận xét:
# - Dữ liệu có tính theo mùa (seasonal) và khuynh hướng (trend) đi lên qua từng năm.

# %% [markdown]
# # Autocorrelation plot

# %%
from pandas.plotting import autocorrelation_plot

# %%
sns.reset_orig()
plt.figure(figsize=(8, 4), dpi= 80)
autocorrelation_plot(df)
plt.show()

# %%
from pandas.plotting import lag_plot
lag_plot(df)
plt.show()

# %% [markdown]
# # Simple Moving Average (SMA)

# %%
SMA_2 = df.rolling(2).mean()
SMA_3 = df.rolling(3).mean()

plt.figure(figsize=(10, 8), dpi=80)
plt.plot(df, color="blue",label="Original Passenger Data")
plt.plot(SMA_2, color="red", label="Simple Moving Average 2")
plt.plot(SMA_3, color="green", label = "Simple Moving Average 3")
plt.title("Sales Amount Time Series, Simple Moving Average")
plt.legend(loc="best")

# %% [markdown]
# # Exponential Moving Average

# %%
EMA_2 = df.ewm(span=2,adjust=False).mean()
EMA_3 = df.ewm(span=3,adjust=False).mean()

plt.figure(figsize=(10, 8), dpi=80)
plt.plot(df,color="blue",label="Original Passenger Data")
plt.plot(EMA_2,color="red",label="Exponential Moving Average 2")
plt.plot(EMA_3,color="green",label="Eponential Moving Average 3")
plt.title("Exponential Moving Average")
plt.legend(loc="best")

# %% [markdown]
# # Sử dụng các mô hình

# %%
X = df.values
train_size = math.floor(len(df) * 0.9)
train, test = X[1 : train_size], X[train_size-1 : ]

# %%
print(train.shape)
train
# Out:
# (31, 1)
# array([[166530.8856],
#        [146783.0066],
#        [174303.7448],
#        [196636.7212],
#        [203857.5194],
#        [213586.6712],
#        [189112.643 ],
#        [201136.1266],
#        [224360.7394],
#        [244457.3994],
#        [243180.1179],
#        [224392.1226],
#        [222381.8508],
#        [206867.5905],
#        [204138.0354],
#        [232380.5285],
#        [246685.0515],
#        [232292.3918],
#        [255736.1928],
#        [240192.9422],
#        [244147.7933],
#        [249710.2827],
#        [291312.4622],
#        [389626.74  ],
#        [355456.08  ],
#        [425369.6   ],
#        [423906.91  ],
#        [462180.26  ],
#        [472585.43  ],
#        [475306.81  ],
#        [483126.86  ]])

# %%
print(test.shape)
test
# Out:
# (5, 1)
# array([[483126.86],
#        [456807.31],
#        [473636.28],
#        [463740.94],
#        [445729.07]])

# %% [markdown]
# ## Auto-regressive

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
auto_reg = AutoReg(train, lags=2)
auto_reg_fit = auto_reg.fit()
print(f"Coefficients: {auto_reg_fit.params}")
# Out:
# Coefficients: [4.77630328e+03 7.75324110e-01 2.59911907e-01]

# %%
predictions = auto_reg_fit.predict(start = len(train),
                                   end = len(train) + len(test) - 1,
                                   dynamic = False)
for i in range(len(predictions)):
    print('predicted = %f, expected = %f' % (predictions[i], test[i]))
rmse = math.sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# predicted = 502894.105421, expected = 483126.860000
# predicted = 520252.651496, expected = 456807.310000
# predicted = 538848.893236, expected = 473636.280000
# predicted = 557778.700625, expected = 463740.940000
# predicted = 577288.821346, expected = 445729.070000
# Test RMSE: 83450.355

# %%
plt.plot(test, label='observed')
plt.plot(predictions, color="red", label='predicted')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima.arima import auto_arima
aa_model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True)
aa_model.fit(train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=705.796, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=701.377, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=700.576, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=701.439, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=703.655, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=701.595, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=702.533, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=703.632, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=705.211, Time=0.01 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 0.215 seconds
# ARIMA(order=(1, 1, 0), scoring_args={}, suppress_warnings=True)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df, order=(1, 1, 0))
results_ARIMA = model.fit()
forecast = results_ARIMA.predict(start = len(train),
                                end = len(train) + len(test) - 1,
                                dynamic = False)
results_ARIMA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            SalesAmount   No. Observations:                   36
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -407.491
# Date:                Mon, 17 Jan 2022   AIC                            818.982
# Time:                        21:24:41   BIC                            822.093
# Sample:                    01-31-2011   HQIC                           820.056
#                          - 12-31-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0675      0.136     -0.495      0.621      -0.335       0.200
# sigma2      7.807e+08   8.21e-11   9.51e+18      0.000    7.81e+08    7.81e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.32   Jarque-Bera (JB):                22.11
# Prob(Q):                              0.57   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.69   Skew:                             1.37
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.26e+35. Standard errors may be unstable.
# """

# %%
results_ARIMA.plot_diagnostics(figsize=(15,12))
plt.show()

# %% [markdown]
# ### Đánh giá mô hình

# %%
prediction = results_ARIMA.get_prediction(start=24, dynamic=False)
prediction_ci = prediction.conf_int()

# %%
ax = df[df.index >= pd.to_datetime('2013-01-01')].plot(label='observed')
prediction.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(prediction_ci.index,
                prediction_ci.iloc[:,0],
                prediction_ci.iloc[:,1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Sales Amount')
plt.title("2013 Sales Amount: observed vs. forecast")
plt.legend()

plt.show()

# %%
# Out:
# The Mean Square Error is 1548707367.21

# %% [markdown]
# ## Dự báo tổng doanh thu (lam phan nay)

# %%
# prediction_2014 = results_ARIMA.predict(start = len(X),
#                                 end = len(X) + 11,
#                                 dynamic = False)
prediction_2014 = results_ARIMA.get_forecast(steps=12)
prediction_2014.conf_int()
# Out:
#             lower SalesAmount  upper SalesAmount
# 2014-01-31      392181.411861      501706.911021
# 2014-02-28      371982.670981      521741.710321
# 2014-03-31      356090.834610      537644.606288
# 2014-04-30      342597.417644      551137.277167
# 2014-05-31      330660.187452      563074.557691
# 2014-06-30      319839.839827      573894.901921
# 2014-07-31      309871.466145      583863.275832
# 2014-08-31      300580.795355      593153.946606
# 2014-09-30      291845.932222      601888.809740
# 2014-10-31      283577.656849      610157.085113
# 2014-11-30      275708.336724      618026.405239
# 2014-12-31      268185.253033      625549.488930

# %%
ax = y.plot(label='observed', figsize=(20,15))
prediction_2014.predicted_mean.plot(ax=ax, label='forecast')
ax.fill_between (prediction_2014.conf_int().index,
                 prediction_2014.conf_int().iloc[:,0],
                 prediction_2014.conf_int().iloc[:,1], color='k', alpha=0.25)

ax.set_xlabel('Month-Year')
ax.set_ylabel("Sales Amount")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-d197f6c25356> in <module>
# ----> 1 ax = y.plot(label='observed', figsize=(20,15))
#       2 prediction_2014.predicted_mean.plot(ax=ax, label='forecast')
#       3 ax.fill_between (prediction_2014.conf_int().index,
#       4                  prediction_2014.conf_int().iloc[:,0],
#       5                  prediction_2014.conf_int().iloc[:,1], color='k', alpha=0.25)
#
# NameError: name 'y' is not defined

# %%
print(prediction_2014)
print(prediction_2014.sum())
# Out:
# 2014-01-31    446944.161441
# 2014-02-28    446862.190651
# 2014-03-31    446867.720449
# 2014-04-30    446867.347406
# 2014-05-31    446867.372572
# 2014-06-30    446867.370874
# 2014-07-31    446867.370988
# 2014-08-31    446867.370981
# 2014-09-30    446867.370981
# 2014-10-31    446867.370981
# 2014-11-30    446867.370981
# 2014-12-31    446867.370981
# Freq: M, Name: predicted_mean, dtype: float64
# 5362480.389285672

# %% [markdown]
# **Tổng doanh thu dự báo của năm 2014: 5,362,480.389**
